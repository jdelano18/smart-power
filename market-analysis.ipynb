# %%
import pandas as pd
import os
import numpy as np
import string

# %%
def search_homes(filename, date, keyword):
    """
    Method that searches through the Data_dump dict structure
    
    Returns:
        vals: dict where keys include keyword and values are counts
        home_count: # of unique homes where the keyword is present
    """
    lennar = pd.read_json(filename)
    clean = lennar.drop_duplicates(subset=['Availability', 'Price', 'Beds', 'Baths', 'Sqft', 'Address', 'Community', 'URL'],
                    keep='first',
                    ignore_index=True)
    
    keyword = keyword.lower()
    vals = dict()
    home_count = 0
    index = 0
    total_features = 0
    
    for d in clean.Data_Dump:
        index += 1
        lines = [item.lower() for sublist in d.values() for item in sublist]
        total_features += len(lines)
    
        # get rid of characters we don't want
        cleaned_lines = [l.strip().replace('\n', '').replace('\r', '').replace('®', '').
                         replace('™','').replace('¹', '').replace('”','') for l in lines]

        # remove punc other than dash
        ultra_cleaned_lines = [cl.translate(str.maketrans('', '', string.punctuation.replace('-',''))) 
                               for cl in cleaned_lines]

        cleaned_words = [i for l in ultra_cleaned_lines for i in l.split()]
        
        if keyword in cleaned_words:
            home_count += 1
    
    return home_count, total_features

# %%
def market_analysis(date, keyword):
    json_files = []
    path = f'./data-{date}/'
    for root, dirs, files in os.walk(path):
        for name in files:
            if name.endswith('.json'):
                json_files.append(root+'/'+name)
                
    df = pd.DataFrame([], columns = ['county', 'state', f'n_homes_{date}', 
                                     f'{keyword}_homes_{date}', f'total_features_{date}'])
    for jf in json_files:
        tmp = pd.read_json(jf)
        state = jf.split('/')[2]
        county = jf.split('/')[3].split('-final')[0]
        n_homes, n_features = search_homes(jf, date, keyword)
        
        if '.ipynb_checkpoints' in county:
            continue

        df.loc[len(df)] = [county, state, tmp.shape[0], n_homes, n_features]
    
    return df

# %%
df1 = market_analysis('06-2023', 'usb')
df1['features_per_home_06-2023'] = df1['total_features_06-2023'] / df1['n_homes_06-2023']

# %%
df1.shape
# Out:
# (70, 6)

# %%
df2 = market_analysis('10-2022', 'usb')
df2['features_per_home_10-2022'] = df2['total_features_10-2022'] / df2['n_homes_10-2022']

# %%
df2.shape
# Out:
# (67, 6)

# %%
counties = df1.merge(df2, on=['county', 'state'], how='outer')

# %%
counties
# Out:
#               county           state  n_homes_06-2023  usb_homes_06-2023  \
# 0            raleigh  north-carolina            177.0                0.0
# 1         wilmington  north-carolina            110.0                0.0
# 2          charlotte  north-carolina            242.0              232.0
# 3         greensboro  north-carolina              3.0                0.0
# 4            chicago        illinois            185.0                0.0
# ..               ...             ...              ...                ...
# 73  inland-northwest      washington              NaN                NaN
# 74           seattle      washington              NaN                NaN
# 75  jefferson-county   west-virginia              NaN                NaN
# 76           madison       wisconsin              NaN                NaN
# 77             tampa         florida              NaN                NaN
#
#     total_features_06-2023  features_per_home_06-2023  n_homes_10-2022  \
# 0                  10884.0                  61.491525            319.0
# 1                   5472.0                  49.745455            103.0
# 2                  20441.0                  84.466942            199.0
# 3                    231.0                  77.000000              NaN
# 4                  13158.0                  71.124324            192.0
# ..                     ...                        ...              ...
# 73                     NaN                        NaN             23.0
# 74                     NaN                        NaN            175.0
# 75                     NaN                        NaN             24.0
# 76                     NaN                        NaN             27.0
# 77                     NaN                        NaN            516.0
#
#     usb_homes_10-2022  total_features_10-2022  features_per_home_10-2022
# 0                 0.0                 23188.0                  72.689655
# 1                 0.0                  5917.0                  57.446602
# 2               171.0                 18411.0                  92.517588
# 3                 NaN                     NaN                        NaN
# 4                 0.0                 12808.0                  66.708333
# ..                ...                     ...                        ...
# 73                0.0                  2429.0                 105.608696
# 74                0.0                 21607.0                 123.468571
# 75                0.0                   310.0                  12.916667
# 76                0.0                    88.0                   3.259259
# 77              167.0                 23780.0                  46.085271
#
# [78 rows x 10 columns]

# %%
states = counties.groupby('state').sum()

# %%
states
# Out:
#                 n_homes_06-2023  usb_homes_06-2023  total_features_06-2023  \
# state
# alabama                   301.0              228.0                 28545.0
# arizona                   319.0               44.0                 13219.0
# california               1516.0             1118.0                 95066.0
# colorado                  218.0                4.0                 13151.0
# delaware                  148.0                8.0                  8486.0
# florida                  1974.0              165.0                 91088.0
# georgia                    93.0                0.0                  4841.0
# idaho                      74.0                0.0                  3819.0
# illinois                  185.0                0.0                 13158.0
# indiana                   346.0                0.0                 29596.0
# maryland                  132.0               12.0                  6641.0
# minnesota                 568.0                0.0                 48753.0
# nevada                    248.0               43.0                  9906.0
# new-jersey                 90.0               38.0                  4954.0
# north-carolina            532.0              232.0                 37028.0
# oklahoma                    8.0                0.0                   432.0
# oregon                    150.0               37.0                  8755.0
# pennsylvania               61.0                0.0                  3385.0
# south-carolina            731.0              307.0                 46076.0
# tennessee                  80.0                0.0                  5315.0
# texas                    1987.0                0.0                 98932.0
# utah                       63.0                0.0                  4658.0
# virginia                   15.0                0.0                    33.0
# washington                  0.0                0.0                     0.0
# west-virginia               0.0                0.0                     0.0
# wisconsin                   0.0                0.0                     0.0
#
#                 features_per_home_06-2023  n_homes_10-2022  usb_homes_10-2022  \
# state
# alabama                        169.867933            175.0              122.0
# arizona                         91.572537            343.0               72.0
# california                     518.590431           1281.0             1089.0
# colorado                        60.325688            277.0              246.0
# delaware                       113.851708            183.0               88.0
# florida                        670.226843           2109.0              167.0
# georgia                        109.092547            105.0                0.0
# idaho                           97.327941             22.0               19.0
# illinois                        71.124324            192.0                0.0
# indiana                        162.189681            296.0                0.0
# maryland                       206.904271            144.0               91.0
# minnesota                       85.832746            665.0                0.0
# nevada                         100.095268            336.0              231.0
# new-jersey                      55.044444            116.0               71.0
# north-carolina                 272.703922            621.0              171.0
# oklahoma                        54.000000              0.0                0.0
# oregon                         172.612560            147.0              147.0
# pennsylvania                   167.232143              9.0                5.0
# south-carolina                 349.604720            397.0               37.0
# tennessee                       66.437500            100.0                0.0
# texas                          249.064360           1900.0                0.0
# utah                            73.936508             74.0                0.0
# virginia                         2.200000             69.0               14.0
# washington                       0.000000            221.0               18.0
# west-virginia                    0.000000             24.0                0.0
# wisconsin                        0.000000             27.0                0.0
#
#                 total_features_10-2022  features_per_home_10-2022
# state
# alabama                        17038.0                 175.266917
# arizona                        16033.0                 113.046444
# california                     84737.0                 454.371362
# colorado                       22229.0                  80.249097
# delaware                       12347.0                 134.926302
# florida                        94061.0                 593.483567
# georgia                         6316.0                 119.692308
# idaho                           1654.0                  75.181818
# illinois                       12808.0                  66.708333
# indiana                        25970.0                 153.719907
# maryland                        6258.0                 195.753448
# minnesota                      60447.0                  90.897744
# nevada                         19270.0                 105.790101
# new-jersey                      8782.0                  75.706897
# north-carolina                 47516.0                 222.653845
# oklahoma                           0.0                   0.000000
# oregon                          9805.0                 135.611862
# pennsylvania                     565.0                 124.000000
# south-carolina                 25916.0                 288.098907
# tennessee                       6974.0                  69.740000
# texas                          99337.0                 204.476779
# utah                            6277.0                  84.824324
# virginia                        2049.0                  80.204082
# washington                     25220.0                 280.555528
# west-virginia                    310.0                  12.916667
# wisconsin                         88.0                   3.259259

# %%
# % changes and save
def percentage_change(col1,col2):
    return round(((col2 - col1) / col1) * 100, 2)

# %%
counties['pct-change-N-homes'] = percentage_change(counties['n_homes_10-2022'],
                                                   counties['n_homes_06-2023'])
counties['pct-change-usb'] = percentage_change(counties['usb_homes_10-2022'],
                                               counties['usb_homes_06-2023'])
counties['pct-change-avg-feats-per-home'] = percentage_change(counties['features_per_home_10-2022'],
                                                              counties['features_per_home_06-2023'])

# %%
counties.to_csv('./analysis/usb-by-county.csv', index=False)

# %%
states['pct-change-N-homes'] = percentage_change(states['n_homes_10-2022'],
                                                 states['n_homes_06-2023'])    
states['pct-change-usb'] = percentage_change(states['usb_homes_10-2022'],
                                             states['usb_homes_06-2023'])
states['pct-change-avg-feats-per-home'] = percentage_change(states['features_per_home_10-2022'],
                                             states['features_per_home_06-2023'])
states.to_csv('./analysis/usb-by-state.csv')
